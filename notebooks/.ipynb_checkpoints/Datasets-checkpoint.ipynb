# %%
import pandas as pd
import pyodbc

conn = pyodbc.connect(
    r'DRIVER={SQL Server};'
    r'SERVER=DESKTOP-BIUMIPC;'
    r'DATABASE=F1_project;'
    r'Trusted_Connection=yes;'
)

query = "SELECT * FROM podium_prediction_dataset"

df = pd.read_sql(query, conn)

df.to_csv(
    r'C:\Users\Dilshani\Documents\F1_project\data\raw\podium_prediction_dataset.csv',
    index=False
)

print(df.head())
# Out:
#   raceId  year round              race_name                    race_date  \
# 0      1  2009     1  Australian Grand Prix  2009-03-29 00:00:00.0000000
# 1      1  2009     1  Australian Grand Prix  2009-03-29 00:00:00.0000000
# 2      1  2009     1  Australian Grand Prix  2009-03-29 00:00:00.0000000
# 3      1  2009     1  Australian Grand Prix  2009-03-29 00:00:00.0000000
# 4      2  2009     2   Malaysian Grand Prix  2009-04-05 00:00:00.0000000
#
#   resultId driverId constructorId   driver_name constructor_name  ...  \
# 0     7556       15             7  Jarno Trulli           Toyota  ...
# 1     7556       15             7  Jarno Trulli           Toyota  ...
# 2     7557       10             7    Timo Glock           Toyota  ...
# 3     7557       10             7    Timo Glock           Toyota  ...
# 4     7577       15             7  Jarno Trulli           Toyota  ...
#
#   constructor_points_last_5 constructor_podium_rate_last_5  avg_pit_ms_last_5  \
# ...
