# %%
import pandas as pd

df= pd.read_csv(r'C:\Users\Dilshani\Documents\F1_project\data\raw\podium_prediction_dataset.csv')

df.describe()
# Out:
# C:\Users\Dilshani\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#              raceId          year         round      resultId      driverId  \
# count  84986.000000  84986.000000  84986.000000  84986.000000  84986.000000
# mean     644.280576   1979.075095      6.772515  15712.837726    381.921587
# std      279.500697     23.968325      5.018951   6901.040572    270.696911
# min        1.000000   1950.000000      1.000000      1.000000      1.000000
# 25%      439.000000   1955.000000      2.000000  10805.000000    119.000000
# 50%      760.000000   1975.000000      6.000000  18640.000000    385.000000
# 75%      809.000000   2000.000000     10.000000  20218.000000    608.000000
# max     1172.000000   2026.000000     24.000000  27331.000000    866.000000
#
# ...

# %%
import sys
sys.path.append('../src')

from preprocessing import preprocess_data

df = preprocess_data(df)

# %%
df.head(10)
# Out:
#    raceId  year  round              race_name  race_date  resultId  driverId  \
# 0       1  2009      1  Australian Grand Prix 2009-03-29      7556        15
# 1       1  2009      1  Australian Grand Prix 2009-03-29      7556        15
# 2       1  2009      1  Australian Grand Prix 2009-03-29      7557        10
# 3       1  2009      1  Australian Grand Prix 2009-03-29      7557        10
# 4       2  2009      2   Malaysian Grand Prix 2009-04-05      7577        15
# 5       2  2009      2   Malaysian Grand Prix 2009-04-05      7577        15
# 6       2  2009      2   Malaysian Grand Prix 2009-04-05      7576        10
# 7       2  2009      2   Malaysian Grand Prix 2009-04-05      7576        10
# 8       3  2009      3     Chinese Grand Prix 2009-04-19      7602         4
# 9       3  2009      3     Chinese Grand Prix 2009-04-19      7602         4
#
#    constructorId      driver_name constructor_name  ...  podium_finish  \
# ...

# %%
df.isnull().sum()
# Out:
# raceId                                   0
# year                                     0
# round                                    0
# race_name                                0
# race_date                                0
# resultId                                 0
# driverId                                 0
# constructorId                            0
# driver_name                              0
# constructor_name                         0
# grid                                     0
# qualifying_position                      0
# best_quali_ms                            0
# qualifying_gap_to_pole_ms                0
# teammate_qualifying_gap_ms               0
# avg_finish_last_5                        0
# podiums_last_5                           0
# avg_qualifying_last_5                    0
# dnf_rate_last_10                         0
# constructor_avg_finish_last_5            0
# constructor_points_last_5                0
# constructor_podium_rate_last_5           0
# ...

# %%
import sys
sys.path.append(r"C:\Users\Dilshani\Documents\F1_project\src")
from predict import make_predictions
import pandas as pd

df = pd.read_csv(
    r"C:\Users\Dilshani\Documents\F1_project\data\raw\podium_prediction_dataset.csv"
)

predicted_df = make_predictions(df)

predicted_df.head()
# Out:
# C:\Users\Dilshani\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-88cd7329f541> in <module>
#       8 )
#       9
# ---> 10 predicted_df = make_predictions(df)
#      11
#      12 predicted_df.head()
#
# ~\Documents\F1_project\src\predict.py in make_predictions(new_data)
#      15 # ------------------------
#      16 def make_predictions(new_data):
# ---> 17     model = joblib.load(MODEL_PATH) # load saved trained model
#      18     feature_columns = joblib.load(FEATURES_PATH) # load saved feature column names
#      19
#
# ~\anaconda3\lib\site-packages\joblib\numpy_pickle.py in load(filename, mmap_mode)
# ...

# %%
import sklearn
import scipy
import numpy

print("sklearn:", sklearn.__version__)
print("scipy:", scipy.__version__)
print("numpy:", numpy.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-4c965c183e70> in <module>
# ----> 1 import sklearn
#       2 import scipy
#       3 import numpy
#       4
#       5 print("sklearn:", sklearn.__version__)
#
# ~\anaconda3\lib\site-packages\sklearn\__init__.py in <module>
#      80     from . import _distributor_init  # noqa: F401
#      81     from . import __check_build  # noqa: F401
# ---> 82     from .base import clone
#      83     from .utils._show_versions import show_versions
#      84
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in <module>
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._tags import (
#      19     _DEFAULT_TAGS,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\__init__.py in <module>
#      20 import warnings
#      21 import numpy as np
# ...
